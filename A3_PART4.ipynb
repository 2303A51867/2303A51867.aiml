# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51867/2303A51867.aiml/blob/main/A3_PART4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from abc import ABC, abstractmethod
import math
import random
from collections import defaultdict

# Game Board class
class GameBoard(defaultdict):
    def __init__(self, *args, **kwargs):
        super().__init__(lambda: ' ')
        self.update(dict(*args, **kwargs))

    def __new__(cls, *args, **kwargs):
        instance = super().__new__(cls)
        return instance

    def __missing__(self, key):
        return ' '

    def __hash__(self):
        return hash(tuple(sorted(self.items())))

    def __repr__(self):
        return f"GameBoard({dict(self)})"

    def display(self):
        lines = []
        for i in range(3):
            lines.append(' | '.join(self[j] for j in range(i * 3, (i + 1) * 3)))
            if i < 2:
                lines.append('---------')
        return '\n'.join(lines)

# Base Game class
class Game(ABC):
    def __init__(self, initial_state=None):
        if initial_state is None:
            initial_state = GameBoard()
        self.initial = initial_state

    @abstractmethod
    def actions(self, state):
        """Return a collection of the allowable moves from this state."""
        pass

    @abstractmethod
    def result(self, state, move):
        """Return the state that results from making a move from a state."""
        pass

    def is_terminal(self, state):
        """Return True if this is a final state for the game."""
        return not self.actions(state) or any(self.utility(state, player) for player in ['X', 'O'])

    @abstractmethod
    def utility(self, state, player):
        """Return the value of this final state to player."""
        pass

    def get_current_player(self, state):
        """Get the current player based on the number of X and O"""
        return 'X' if state.values().count('X') <= state.values().count('O') else 'O'

# TicTacToe game subclass
class TicTacToe(Game):
    def __init__(self, initial_state=None):
        if initial_state is None:
            initial_state = GameBoard()
        super().__init__(initial_state)

    def actions(self, state):
        return [i for i, cell in state.items() if cell == ' ']

    def result(self, state, move):
        new_state = GameBoard(state)
        new_state[move] = 'X'  # Assume 'X' is the current player
        return new_state

    def is_terminal(self, state):
        return not self.actions(state) or any(self.utility(state, player) for player in ['X', 'O'])

    def utility(self, state, player):
        # Utility function to evaluate the state
        winning_positions = [
            (0, 1, 2), (3, 4, 5), (6, 7, 8),  # Rows
            (0, 3, 6), (1, 4, 7), (2, 5, 8),  # Columns
            (0, 4, 8), (2, 4, 6)              # Diagonals
        ]
        for a, b, c in winning_positions:
            if state[a] == state[b] == state[c] == player:
                return 1 if player == 'X' else -1
        return 0

    def display(self, state):
        return state.display()

# MiniMax Search Algorithm
def minimax_search(game, state):
    """Search game tree to determine the best move; return (value, move) pair."""
    player = game.get_current_player(state)

    def max_value(state):
        if game.is_terminal(state):
            return game.utility(state, player), None
        v, move = -math.inf, None
        for a in game.actions(state):
            v2, _ = min_value(game.result(state, a))
            if v2 > v:
                v, move = v2, a
        return v, move

    def min_value(state):
        if game.is_terminal(state):
            return game.utility(state, player), None
        v, move = math.inf, None
        for a in game.actions(state):
            v2, _ = max_value(game.result(state, a))
            if v2 < v:
                v, move = v2, a
        return v, move

    return max_value(state)

# Alpha-Beta Search Algorithm
def alphabeta_search(game, state):
    """Search game to determine the best action; use alpha-beta pruning."""
    player = game.get_current_player(state)

    def max_value(state, alpha, beta):
        if game.is_terminal(state):
            return game.utility(state, player), None
        v, move = -math.inf, None
        for a in game.actions(state):
            v2, _ = min_value(game.result(state, a), alpha, beta)
            if v2 > v:
                v, move = v2, a
            alpha = max(alpha, v)
            if v >= beta:
                return v, move
        return v, move

    def min_value(state, alpha, beta):
        if game.is_terminal(state):
            return game.utility(state, player), None
        v, move = math.inf, None
        for a in game.actions(state):
            v2, _ = max_value(game.result(state, a), alpha, beta)
            if v2 < v:
                v, move = v2, a
            beta = min(beta, v)
            if v <= alpha:
                return v, move
        return v, move

    return max_value(state, -math.inf, math.inf)

# Function to play the game
def play_game(game, strategies, verbose=False):
    """Play a turn-taking game. ‘strategies‘ is a {player name: function} dict,
    where function(state, game) is used to get the player’s move."""
    state = game.initial
    while not game.is_terminal(state):
        player = game.get_current_player(state)
        move = strategies[player](game, state)
        state = game.result(state, move)
        if verbose:
            print(f'Player {player} move: {move}')
            print(game.display(state))
    return state

# Strategy functions
def random_strategy(game, state):
    return random.choice(game.actions(state))

def minimax_strategy(game, state):
    """Use the MiniMax algorithm to determine the best move."""
    _, move = minimax_search(game, state)
    return move

def alphabeta_strategy(game, state):
    """Use Alpha-Beta pruning to determine the best move."""
    _, move = alphabeta_search(game, state)
    return move

# Evaluate AI Strategies
def evaluate_strategies():
    print("Evaluating strategy: X (Random) vs O (Alpha-Beta)")
    game = TicTacToe()
    strategies = {'X': random_strategy, 'O': alphabeta_strategy}
    final_state = play_game(game, strategies, verbose=True)
    print("Final state:")
    print(game.display(final_state))
    print("Utility for 'X':", game.utility(final_state, 'X'))
    print("Utility for 'O':", game.utility(final_state, 'O'))
    print()

    print("Evaluating strategy: X (Alpha-Beta) vs O (MiniMax)")
    game = TicTacToe()
    strategies = {'X': alphabeta_strategy, 'O': minimax_strategy}
    final_state = play_game(game, strategies, verbose=True)
    print("Final state:")
    print(game.display(final_state))
    print("Utility for 'X':", game.utility(final_state, 'X'))
    print("Utility for 'O':", game.utility(final_state, 'O'))

# Run evaluations
if __name__ == "__main__":
    evaluate_strategies()
# Out:
# Evaluating strategy: X (Random) vs O (Alpha-Beta)
# Final state:
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# Utility for 'X': 0
# Utility for 'O': 0
#
# Evaluating strategy: X (Alpha-Beta) vs O (MiniMax)
# Final state:
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# Utility for 'X': 0
# Utility for 'O': 0
